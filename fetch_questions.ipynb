# %%
import requests
from bs4 import BeautifulSoup

# Step 1: Fetch the web page
url = 'https://leetcode.cn/studyplan/selected-coding-interview/'  # Replace with the actual URL

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36'
}

response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Step 2: Parse the HTML
    soup = BeautifulSoup(response.content.decode(), 'html.parser')

    # Step 3: Find all <div> elements with class 'truncate'
    divs = soup.find_all('div', class_='truncate')
    
    # Step 4: Extract the text from each <div>
    texts = [div.get_text(strip=True) for div in divs]

    # Print the texts
    for i, text in enumerate(texts):
        print(f'Text in <div class="truncate">[{i}]: {text}')
else:
    print(f'Failed to retrieve the webpage. Status code: {response.status_code}')
# Out:
# Text in <div class="truncate">[0]: 倾力打造算法备考首选题单
# Text in <div class="truncate">[1]: Krahets 笔面试精选 88 题

# %%
response.content.decode()
# Out:
# '<!DOCTYPE html><html lang="zh"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:site" content="@LeetCode"/><meta property="og:locale" content="zh_CN"/><meta property="og:site_name" content="力扣 LeetCode"/><title>Krahets 笔面试精选 88 题 - 学习计划 - 力扣（LeetCode）全球极客挚爱的技术成长平台</title><meta name="robots" content="index,follow"/><meta name="description" content="倾力打造算法备考首选题单"/><meta property="og:title" content="Krahets 笔面试精选 88 题 - 学习计划 - 力扣（LeetCode）全球极客挚爱的技术成长平台"/><meta property="og:description" content="倾力打造算法备考首选题单"/><meta property="og:image" content="https://pic.leetcode.cn/1692094558-EXkzrr-Krahets%20ad.png"/><meta name="next-head-count" content="12"/><script type="text/javascript"></script><link rel="preload" href="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/css/30fcc075d9a99f3c.css" as="style"/><link rel="stylesheet" href="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/css/30fcc075d9a99f3c.css" data-n-g=""/><link rel="preload" href="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/css/dc2fd5a0692eeb47.css" as="style"/><link rel="stylesheet" href="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/css/dc2fd5a0692eeb47.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/webpack-05f20a3db2b8bb90.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/framework-f4a03e6ac5f7da26.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/main-841145f14f0fa3df.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/pages/_app-6cc35ef76c59b19e.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/c829854d-64219f161c6a5d8c.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/ee9ce975-045f592dc415d445.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/c46d6b60-8a1f5f7d1a9c2ea8.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/58a3678d-972e97c25f9a1858.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/8740-82d3b9fb02874e2f.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/1931-f621419104f565a5.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/9906-4d01194c51a2ce1d.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/7512-30bf067258f7b7e6.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/67-29cf5d95225cd86f.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/8774-bb88d92c8e997441.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/8485-c8c7dbabd20a9a85.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/48-486d0f9541d0d869.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/8872-a380df774af91413.js" defer=""></script><script src="https://static.leetcode.cn/cn-frontendx-assets/production/_next/static/chunks/1850-59101104a81f063c.js" defer=""></script><script  ...

# %%
soup.find_all("script", type=r"application/json")[0].get_text()
# Out:
# '{"props":{"pageProps":{"dehydratedState":{"mutations":[],"queries":[{"state":{"data":{"studyPlanV2Detail":{"slug":"selected-coding-interview","name":"Krahets 笔面试精选 88 题","highlight":"倾力打造算法备考首选题单","staticCoverPicture":"https://pic.leetcode.cn/1692094558-EXkzrr-Krahets%20ad.png","colorPalette":"blue","threeDimensionUrl":null,"description":"适合作为互联网求职者的第一份题库\\r\\n图文详解题目，覆盖主要算法知识点\\r\\n均为大厂高频题，可使笔面试备考事半功倍\\r\\n提供简洁的 Java, Python, C++ 解题代码","premiumOnly":false,"needShowTags":false,"awardDescription":"解决所有问题后，你将会获得此学习计划勋章","defaultLanguage":null,"award":null,"relatedStudyPlans":[{"cover":"https://assets.leetcode.cn/aliyun-lc-upload/study_plan_v2/top-interview-150/cover","highlight":"最经典 150 题，掌握面试所有知识点","name":"面试经典 150 题","slug":"top-interview-150","premiumOnly":false},{"cover":"https://assets.leetcode.cn/aliyun-lc-upload/study_plan_v2/leetcode-75/cover","highlight":"面试必考精华版，75 题覆盖全量考点","name":"LeetCode 75","slug":"leetcode-75","premiumOnly":false},{"cover":"https://assets.leetcode.cn/aliyun-lc-upload/study_plan_v2/premium-algo-100/cover","highlight":"会员专享题单 = 包含更多真实面试题","name":"尊享面试 100 题","slug":"premium-algo-100","premiumOnly":true},{"cover":"https://assets.leetcode.cn/aliyun-lc-upload/study_plan_v2/bytedance-2023-fall-sprint/cover","highlight":"秋招弯道顺利超车","name":"字节跳动秋招心动计划","slug":"bytedance-2023-fall-sprint","premiumOnly":true},{"cover":"https://assets.leetcode.cn/aliyun-lc-upload/study_plan_v2/top-100-liked/cover","highlight":"力扣最受刷题发烧友欢迎的 100 道题","name":"LeetCode 热题 100","slug":"top-100-liked","premiumOnly":false}],"planSubGroups":[{"slug":"selected-coding-interview-313-fueu","name":"链表","premiumOnly":false,"questionNum":5,"questions":[{"translatedTitle":"合并两个有序链表","titleSlug":"merge-two-sorted-lists","title":"Merge Two Sorted Lists","questionFrontendId":"21","paidOnly":false,"id":"21","difficulty":"EASY","topicTags":[{"slug":"recursion","nameTranslated":"递归","name":"Recursion"},{"slug":"linked-list","nameTranslated":"链表","name":"Linked List"}],"solutionInfo":{"solutionSlug":"21-he-bing-liang-ge-you-xu-lian-biao-shu-aisw","solutionTopicId":2361535}},{"translatedTitle":"反转链表","titleSlug":"reverse-linked-list","title":"Reverse Linked List","questionFrontendId":"206","paidOnly":false,"id":"206","difficulty":"EASY","topicTags":[{"slug":"recursion","nameTranslated":"递归","name":"Recursion"},{"slug":"linked-list","nameTranslated":"链表","name":"Linked List"}],"solutionInfo":{"solutionSlug":"206-fan-zhuan-lian-biao-shuang-zhi-zhen-r1jel","solutionTopicId":2361282}},{"translatedTitle":"分隔链表","titleSlug":"partition-list","title":"Partition List","questionFrontendId":"86","paidOnly":false,"id":"86","difficulty":"MEDIUM","topicTags":[{"slug":"linked-list","nameTranslated":"链表","name":"Linked List"},{"slug":"two-pointers","nameTranslated":"双指针","name":"Two Pointers"}],"solutionInfo":{"solutionSlug":"86-fen-ge-lian-biao-shuang-zhi-zhen-qing-hha7","solutionTopicId":2362068}},{"translatedTitle":"删除链表中的节点","titleSlug":"delete-node-in-a-linked-list","title":"Delete Node in a Linked List","questionFrontendId":"237","paidOnly":false,"id":"237","difficulty":"MEDIUM","topicTags":[{"slug":"linked-list","nameTranslated":"链表","name":"Linked List"}],"solutionInfo":{"solutionSlug":"237-shan-chu-lian-biao-zhong-de-jie-dian-zli2","solutionTopicId":2362069}},{"translatedTitle":"随机链表的复制","titleSlug":"copy-list-with-random-pointer","title":"Copy List with Random Pointer","questionFrontendId":"138","paidOnly":false,"id":"138","difficulty":"MEDIUM","topicTags":[{"slug":"hash-table","nameTranslated":"哈希表","name":"Hash Table"},{"slug":"linked-list","nameTranslated":"链表","name":"Linked List"}],"solutionInfo":{"solutionSlug":"138-fu-zhi-dai-sui-ji-zhi-zhen-de-lian-b-6jeo","solutionTopicId":2361362}}]},{"slug":"selected-coding-interview-314-j0ja","name":"栈与队列","premiumOnly":false,"questionNum":5,"questions":[{"translatedTitle":"有效的括号","titleSlug":"valid-parentheses","title":"Valid Parentheses","questionFrontendId":"20","paidOnly":false,"id":"20","difficulty":"EASY ...

# %%
import json
json_data = json.loads(soup.find_all("script", type=r"application/json")[0].get_text())
sub_groups = json_data["props"]['pageProps']['dehydratedState']['queries'][0]['state']['data']['studyPlanV2Detail']['planSubGroups']

# %%
sub_groups[0]['questions'][0]
# Out:
# {'translatedTitle': '合并两个有序链表',
#  'titleSlug': 'merge-two-sorted-lists',
#  'title': 'Merge Two Sorted Lists',
#  'questionFrontendId': '21',
#  'paidOnly': False,
#  'id': '21',
#  'difficulty': 'EASY',
#  'topicTags': [{'slug': 'recursion',
#    'nameTranslated': '递归',
#    'name': 'Recursion'},
#   {'slug': 'linked-list', 'nameTranslated': '链表', 'name': 'Linked List'}],
#  'solutionInfo': {'solutionSlug': '21-he-bing-liang-ge-you-xu-lian-biao-shu-aisw',
#   'solutionTopicId': 2361535}}

# %%
res_dict = {}
for subgroup in sub_groups:
    subgroup_name = subgroup['name']
    res_dict[subgroup_name] = []
    questions = subgroup['questions']
    for question in questions:
        ques_dict = {}
        ques_dict['title'] = question['titleSlug']
        ques_dict['id'] = question['id']
        ques_dict['translatedTitle'] = question['translatedTitle']
        ques_dict['tag'] = ''
        tags = question['topicTags']
        # for tag in tags:
        for i in range(len(tags)):
            tag = tags[i]
            if i == len(tags) - 1:
                ques_dict['tag'] += tag['name']
            else:
                ques_dict['tag'] += tag['name'] + ", "
        res_dict[subgroup_name].append(ques_dict)

# %%
res_dict['链表']
# Out:
# [{'title': 'merge-two-sorted-lists',
#   'id': '21',
#   'translatedTitle': '合并两个有序链表',
#   'tag': 'Recursion, Linked List'},
#  {'title': 'reverse-linked-list',
#   'id': '206',
#   'translatedTitle': '反转链表',
#   'tag': 'Recursion, Linked List'},
#  {'title': 'partition-list',
#   'id': '86',
#   'translatedTitle': '分隔链表',
#   'tag': 'Linked List, Two Pointers'},
#  {'title': 'delete-node-in-a-linked-list',
#   'id': '237',
#   'translatedTitle': '删除链表中的节点',
#   'tag': 'Linked List'},
#  {'title': 'copy-list-with-random-pointer',
#   'id': '138',
#   'translatedTitle': '随机链表的复制',
#   'tag': 'Hash Table, Linked List'}]

# %%
with open('question_list.md', 'w') as f:
    for key in res_dict.keys():
        f.write(f"## {key}\n\n")
        for question_dict in res_dict[key]:
            f.write(f"### {question_dict['translatedTitle']}\n\n- id: {question_dict['id']}\n- name: {question_dict['title']}\n- tag: {question_dict['tag']}\n\n")
        f.write('\n--- \n\n\n')
